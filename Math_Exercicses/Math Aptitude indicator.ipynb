# %% [markdown]
# ## Math aptitude indicator

# %%
from IPython.display import Math, display
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# The second order derivative

# %%
display(Math('\\frac{d^²f}{dx} \\text{ of} f(x)=xexp(-x)'))
# Out:
# $\displaystyle \frac{d^²f}{dx} \text{ of} f(x)=xexp(-x)$

# %%
PATH = "/home/nesov/Downloads/"
Image(filename = PATH + "IMG_2864.jpg", width=800, height=600)

# %% [markdown]
# Calculate

# %%
display(Math('\\lim_{x\\to 0}\\frac{2x+sinx}{x(x-1)}'))
# Out:
# $\displaystyle \lim_{x\to 0}\frac{2x+sinx}{x(x-1)}$

# %%
PATH = "/home/nesov/Downloads/"
Image(filename = PATH + "IMG_2865.jpg", width=800, height=600)

# %% [markdown]
# What is the value of the limiting problem:

# %%
display(Math('\\lim_{h\\to 0}\\frac{(x+h)^3-x^3}{h}'))
# Out:
# $\displaystyle \lim_{h\to 0}\frac{(x+h)^3-x^3}{h}$

# %%
PATH = "/home/nesov/Downloads/"
Image(filename = PATH + "IMG_2867.jpg", width=800, height=600)

# %%
display(Math('\\int_{0}^{\infty}xexp(-x^2)dx'))
# Out:
# $\displaystyle \int_{0}^{\infty}xexp(-x^2)dx$

# %%
PATH = "/home/nesov/Downloads/"

Image(filename = PATH + "IMG_2943.jpg", width=800, height=600)

# %%
Image(filename = PATH + "IMG_2944.jpg", width=800, height=600)

# %% [markdown]
# Evaluate the following integral:

# %%
display(Math('\\int_{0}^{1}\\frac{dx}{x^2+3x+2}'))
# Out:
# $\displaystyle \int_{0}^{1}\frac{dx}{x^2+3x+2}$
